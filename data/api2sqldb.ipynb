# %%
import cbsodata
from google.cloud import bigquery
import pandas as pd
import sqlite3
from tqdm import tqdm

# %%
def check_language_count(tables):
    eng_count = 0
    ned_count = 0
    # iterate over the list of dictionaries
    for table in tables:
        language = table.get('Language', '')
        if  language.endswith('en'):
            eng_count += 1
        elif language.endswith('nl'):
            ned_count += 1
        else:
            print(table.get('Identifier', ''))
    print(f"Number of 'ENG': {eng_count}")
    print(f"Number of 'NED': {ned_count}")

def return_english_tables(tables):
    eng_tables = []
    for table in tables:
        language = table.get('Language', '')
        if  language.endswith('en'):
            identifier = table.get('Identifier', '')
            eng_tables.append(identifier)
    return eng_tables    

def check_col_names(table, metadata):
    # extracting the column names from the 'table' dataset
    table_columns = table.columns.tolist()

    # extracting the 'Key' values from the 'metadata' dataset
    key_values = metadata['Key'].dropna().tolist()  # Remove NaN values from the 'Key' column

    # finding matches between table columns and key values
    matches = [col for col in table_columns if col in key_values]

    # finding non-matching columns
    non_matches = [col for col in table_columns if col not in key_values]

    # Output results
    print("Matching columns:", matches, len(matches))
    print("Non-matching columns:", non_matches, len(non_matches))

# %%
tables = cbsodata.get_table_list()
check_language_count(tables)
# retrieve specific table with identifier
table = pd.DataFrame(cbsodata.get_data('37105ENG'))
print(table.columns)
# retrieve metadata of specific table
metadata = pd.DataFrame(cbsodata.get_meta('37105ENG',name= 'DataProperties')) 
print(metadata)
# check if keys in metadata are corresponding to the columns in the actual dataset
check_col_names(table, metadata)
# Out:
# Number of 'ENG': 1026
# Number of 'NED': 4729
# Index(['ID', 'Regions', 'Periods', 'TotalSurface_1', 'TransportTotal_2',
#        'Railroad_3', 'MainRoad_4', 'Airport_5', 'BuiltUpAreaTotal_6',
#        'Residential_7', 'IndustryBusinessPublicInstitutions_8',
#        'SocioCulturalFacilities_9', 'SemiBuiltUpAreaTotal_10', 'MiningArea_11',
#        'BuildingSite_12', 'OtherSemiBuiltUpArea_13', 'RecreationTotal_14',
#        'ParkAndPublicGarden_15', 'SportGrounds_16', 'OtherRecreationUsage_17',
#        'AgricultureTotal_18', 'Greenhouses_19', 'OtherAgriculturalUsage_20',
#        'WoodlandAndNatureTotal_21', 'Woodland_22', 'NaturalOpenArea_23',
#        'WaterTotal_24', 'InlandWaterTotal_25', 'TidalWaterTotal_26'],
#       dtype='object')
#                  odata.type  ID  Position  ParentID           Type  \
# 0    Cbs.OData.GeoDimension   0       0.0       NaN   GeoDimension
# 1   Cbs.OData.TimeDimension   1       1.0       NaN  TimeDimension
# 2           Cbs.OData.Topic   2       2.0       NaN          Topic
# 3      Cbs.OData.TopicGroup   3       NaN       NaN     TopicGroup
# 4           Cbs.OData.Topic   4       3.0       3.0          Topic
# 5           Cbs.OData.Topic   5       4.0       3.0          Topic
# 6           Cbs.OData.Topic   6       5.0       3.0          Topic
# 7           Cbs.OData.Topic   7       6.0       3.0          Topic
# 8      Cbs.OData.TopicGroup   8       NaN       NaN     TopicGroup
# 9           Cbs.OData.Topic   9       7.0       8.0          Topic
# 10          Cbs.OData.Topic  10       8.0       8.0          Topic
# 11          Cbs.OData.Topic  11       9.0       8.0          Topic
# 12          Cbs.OData.Topic  12      10.0       8.0          Topic
# 13     Cbs.OData.TopicGroup  13       NaN       NaN     TopicGroup
# 14          Cbs.OData.Topic  14      11.0      13.0          Topic
# 15          Cbs.OData.Topic  15      12.0      13.0          Topic
# 16          Cbs.OData.Topic  16      13.0      13.0          Topic
# 17          Cbs.OData.Topic  17      14.0      13.0          Topic
# 18     Cbs.OData.TopicGroup  18       NaN       NaN     TopicGroup
# 19          Cbs.OData.Topic  19      15.0      18.0          Topic
# 20          Cbs.OData.Topic  20      16.0      18.0          Topic
# 21          Cbs.OData.Topic  21      17.0      18.0          Topic
# 22          Cbs.OData.Topic  22      18.0      18.0          Topic
# 23     Cbs.OData.TopicGroup  23       NaN       NaN     TopicGroup
# 24          Cbs.OData.Topic  24      19.0      23.0          Topic
# 25          Cbs.OData.Topic  25      20.0      23.0          Topic
# 26          Cbs.OData.Topic  26      21.0      23.0          Topic
# 27     Cbs.OData.TopicGroup  27       NaN       NaN     TopicGroup
# 28          Cbs.OData.Topic  28      22.0      27.0          Topic
# 29          Cbs.OData.Topic  29      23.0      27.0          Topic
# 30          Cbs.OData.Topic  30      24.0      27.0          Topic
# 31     Cbs.OData.TopicGroup  31       NaN       NaN     TopicGroup
# 32          Cbs.OData.Topic  32      25.0      31.0          Topic
# 33          Cbs.OData.Topic  33      26.0      31.0          Topic
# 34          Cbs.OData.Topic  34      27.0      31.0          Topic
#
#                                      Key  \
# 0                                Regions
# 1                                Periods
# 2                         TotalSurface_1
# 3
# 4                       TransportTotal_2
# 5                             Railroad_3
# 6                             MainRoad_4
# 7                              Airport_5
# 8
# 9                     BuiltUpAreaTotal_6
# 10                         Residential_7
# 11  IndustryBusinessPublicInstitutions_8
# 12             SocioCulturalFacilities_9
# 13
# 14               SemiBuiltUpAreaTotal_10
# 15                         MiningArea_11
# 16                       BuildingSite_12
# 17               OtherSemiBuiltUpArea_13
# 18
# 19                    RecreationTotal_14
# 20                ParkAndPublicGarden_15
# 21                       SportGrounds_16
# 22               OtherRecreationUsage_17
# 23
# 24                   AgricultureTotal_18
# 25                        Greenhouses_19
# 26             OtherAgriculturalUsage_20
# 27
# 28             WoodlandAndNatureTotal_21
# 29                           Woodland_22
# 30                    NaturalOpenArea_23
# 31
# 32                         WaterTotal_24
# 33                   InlandWaterTotal_25
# 34                    TidalWaterTotal_26
#
#                                       Title  \
# 0                                   Regions
# 1                                   Periods
# 2                             Total surface
# 3                                 Transport
# 4                           Transport total
# 5                                  Railroad
# 6                                 Main road
# 7                                   Airport
# 8                             Built-up area
# 9                       Built-up area total
# 10                              Residential
# 11  Industry, business, public institutions
# 12                Socio-cultural facilities
# 13                       Semi built-up area
# 14                 Semi built-up area total
# 15                              Mining area
# 16                            Building site
# 17                 Other semi built-up area
# 18                               Recreation
# 19                         Recreation total
# 20                   Park and public garden
# 21                            Sport grounds
# 22                   Other recreation usage
# 23                              Agriculture
# 24                        Agriculture total
# 25                              Greenhouses
# 26                 Other agricultural usage
# 27                      Woodland and nature
# 28                Woodland and nature total
# 29                                 Woodland
# 30                        Natural open area
# 31                                    Water
# 32                              Water total
# 33                       Inland water total
# 34                        Tidal water total
#
#                                           Description  MapYear ReleasePolicy  \
# 0                                                          NaN           NaN
# 1                                                          NaN         False
# 2                   Total surface of the Netherlands.      NaN           NaN
# 3   Area in use for traffic and transport on roads...      NaN           NaN
# 4           Total area of the main group ‘Transport’.      NaN           NaN
# 5   Area in use for traffic and transport on railw...      NaN           NaN
# 6   Area in use for traffic and transport over the...      NaN           NaN
# 7   Area in use for traffic and transport in the a...      NaN           NaN
# 8   Area in use for residents, work, shopping, cul...      NaN           NaN
# 9       Total area of the main group ‘Built-on area’.      NaN           NaN
# 10  Area mainly used for residents, including prim...      NaN           NaN
# 11  Area in use for industry, retail and business ...      NaN           NaN
# 12  Area in use by social and cultural facilities ...      NaN           NaN
# 13  Area with a certain amount of paving, not in u...      NaN           NaN
# 14  Total area of the main group ‘Semi built-up ar...      NaN           NaN
# 15  Area for winning materials from the bottom or ...      NaN           NaN
# 16  Area in use for construction.\r\n\r\nincluding...      NaN           NaN
# 17  Area of other use with a certain amount of pav...      NaN           NaN
# 18                        Area in use for recreation.      NaN           NaN
# 19         Total area of the main group ‘Recreation’.      NaN           NaN
# 20  Green area in use for relaxation.\r\n\r\nInclu...      NaN           NaN
# 21  Area in use for sport activities.\r\n\r\nInclu...      NaN           NaN
# 22  Area of allotment gardens, for daytrips like z...      NaN           NaN
# 23                              Area for agriculture.      NaN           NaN
# 24        Total area of the main group ‘Agriculture’.      NaN           NaN
# 25  Area in use for agriculture in greenhouses.\r\...      NaN           NaN
# 26  Area for agriculture without glass, like pastu...      NaN           NaN
# 27             Area with forest or natural open area.      NaN           NaN
# 28  Total area of the main group ‘Woodland and nat...      NaN           NaN
# 29  Area with trees for wood production and nature...      NaN           NaN
# 30  Open area with a wet or dry surface, mainly na...      NaN           NaN
# 31                                               None      NaN           NaN
# 32               Total area of the main group ‘Water’      NaN           NaN
# 33  Inland water in use as waterway, recreational ...      NaN           NaN
# 34               Water outside the average high tide.      NaN           NaN
#
#    Datatype Unit  Decimals     Default PresentationType
# 0       NaN  NaN       NaN         NaN              NaN
# 1       NaN  NaN       NaN         NaN              NaN
# 2      Long  km2       0.0  Impossible         Absolute
# 3       NaN  NaN       NaN         NaN              NaN
# 4      Long  km2       0.0  Impossible         Absolute
# 5      Long  km2       0.0  Impossible         Absolute
# 6      Long  km2       0.0  Impossible         Absolute
# 7      Long  km2       0.0  Impossible         Absolute
# 8       NaN  NaN       NaN         NaN              NaN
# 9      Long  km2       0.0  Impossible         Absolute
# 10     Long  km2       0.0  Impossible         Absolute
# 11     Long  km2       0.0  Impossible         Absolute
# 12     Long  km2       0.0  Impossible         Absolute
# 13      NaN  NaN       NaN         NaN              NaN
# 14     Long  km2       0.0  Impossible         Absolute
# 15     Long  km2       0.0  Impossible         Absolute
# 16     Long  km2       0.0  Impossible         Absolute
# 17     Long  km2       0.0  Impossible         Absolute
# 18      NaN  NaN       NaN         NaN              NaN
# 19     Long  km2       0.0  Impossible         Absolute
# 20     Long  km2       0.0  Impossible         Absolute
# 21     Long  km2       0.0  Impossible         Absolute
# 22     Long  km2       0.0  Impossible         Absolute
# 23      NaN  NaN       NaN         NaN              NaN
# 24     Long  km2       0.0  Impossible         Absolute
# 25     Long  km2       0.0  Impossible         Absolute
# 26     Long  km2       0.0  Impossible         Absolute
# 27      NaN  NaN       NaN         NaN              NaN
# 28     Long  km2       0.0  Impossible         Absolute
# 29     Long  km2       0.0  Impossible         Absolute
# 30     Long  km2       0.0  Impossible         Absolute
# 31      NaN  NaN       NaN         NaN              NaN
# 32     Long  km2       0.0  Impossible         Absolute
# 33     Long  km2       0.0  Impossible         Absolute
# 34     Long  km2       0.0  Impossible         Absolute
# Matching columns: ['Regions', 'Periods', 'TotalSurface_1', 'TransportTotal_2', 'Railroad_3', 'MainRoad_4', 'Airport_5', 'BuiltUpAreaTotal_6', 'Residential_7', 'IndustryBusinessPublicInstitutions_8', 'SocioCulturalFacilities_9', 'SemiBuiltUpAreaTotal_10', 'MiningArea_11', 'BuildingSite_12', 'OtherSemiBuiltUpArea_13', 'RecreationTotal_14', 'ParkAndPublicGarden_15', 'SportGrounds_16', 'OtherRecreationUsage_17', 'AgricultureTotal_18', 'Greenhouses_19', 'OtherAgriculturalUsage_20', 'WoodlandAndNatureTotal_21', 'Woodland_22', 'NaturalOpenArea_23', 'WaterTotal_24', 'InlandWaterTotal_25', 'TidalWaterTotal_26'] 28
# Non-matching columns: ['ID'] 1

# %%
print(metadata)
# Out:
#                  odata.type  ID  Position  ParentID           Type  \
# 0    Cbs.OData.GeoDimension   0       0.0       NaN   GeoDimension
# 1   Cbs.OData.TimeDimension   1       1.0       NaN  TimeDimension
# 2           Cbs.OData.Topic   2       2.0       NaN          Topic
# 3      Cbs.OData.TopicGroup   3       NaN       NaN     TopicGroup
# 4           Cbs.OData.Topic   4       3.0       3.0          Topic
# 5           Cbs.OData.Topic   5       4.0       3.0          Topic
# 6           Cbs.OData.Topic   6       5.0       3.0          Topic
# 7           Cbs.OData.Topic   7       6.0       3.0          Topic
# 8      Cbs.OData.TopicGroup   8       NaN       NaN     TopicGroup
# 9           Cbs.OData.Topic   9       7.0       8.0          Topic
# 10          Cbs.OData.Topic  10       8.0       8.0          Topic
# 11          Cbs.OData.Topic  11       9.0       8.0          Topic
# 12          Cbs.OData.Topic  12      10.0       8.0          Topic
# 13     Cbs.OData.TopicGroup  13       NaN       NaN     TopicGroup
# 14          Cbs.OData.Topic  14      11.0      13.0          Topic
# 15          Cbs.OData.Topic  15      12.0      13.0          Topic
# 16          Cbs.OData.Topic  16      13.0      13.0          Topic
# 17          Cbs.OData.Topic  17      14.0      13.0          Topic
# 18     Cbs.OData.TopicGroup  18       NaN       NaN     TopicGroup
# 19          Cbs.OData.Topic  19      15.0      18.0          Topic
# 20          Cbs.OData.Topic  20      16.0      18.0          Topic
# 21          Cbs.OData.Topic  21      17.0      18.0          Topic
# 22          Cbs.OData.Topic  22      18.0      18.0          Topic
# 23     Cbs.OData.TopicGroup  23       NaN       NaN     TopicGroup
# 24          Cbs.OData.Topic  24      19.0      23.0          Topic
# 25          Cbs.OData.Topic  25      20.0      23.0          Topic
# 26          Cbs.OData.Topic  26      21.0      23.0          Topic
# 27     Cbs.OData.TopicGroup  27       NaN       NaN     TopicGroup
# 28          Cbs.OData.Topic  28      22.0      27.0          Topic
# 29          Cbs.OData.Topic  29      23.0      27.0          Topic
# 30          Cbs.OData.Topic  30      24.0      27.0          Topic
# 31     Cbs.OData.TopicGroup  31       NaN       NaN     TopicGroup
# 32          Cbs.OData.Topic  32      25.0      31.0          Topic
# 33          Cbs.OData.Topic  33      26.0      31.0          Topic
# 34          Cbs.OData.Topic  34      27.0      31.0          Topic
#
#                                      Key  \
# 0                                Regions
# 1                                Periods
# 2                         TotalSurface_1
# 3
# 4                       TransportTotal_2
# 5                             Railroad_3
# 6                             MainRoad_4
# 7                              Airport_5
# 8
# 9                     BuiltUpAreaTotal_6
# 10                         Residential_7
# 11  IndustryBusinessPublicInstitutions_8
# 12             SocioCulturalFacilities_9
# 13
# 14               SemiBuiltUpAreaTotal_10
# 15                         MiningArea_11
# 16                       BuildingSite_12
# 17               OtherSemiBuiltUpArea_13
# 18
# 19                    RecreationTotal_14
# 20                ParkAndPublicGarden_15
# 21                       SportGrounds_16
# 22               OtherRecreationUsage_17
# 23
# 24                   AgricultureTotal_18
# 25                        Greenhouses_19
# 26             OtherAgriculturalUsage_20
# 27
# 28             WoodlandAndNatureTotal_21
# 29                           Woodland_22
# 30                    NaturalOpenArea_23
# 31
# 32                         WaterTotal_24
# 33                   InlandWaterTotal_25
# 34                    TidalWaterTotal_26
#
#                                       Title  \
# 0                                   Regions
# 1                                   Periods
# 2                             Total surface
# 3                                 Transport
# 4                           Transport total
# 5                                  Railroad
# 6                                 Main road
# 7                                   Airport
# 8                             Built-up area
# 9                       Built-up area total
# 10                              Residential
# 11  Industry, business, public institutions
# 12                Socio-cultural facilities
# 13                       Semi built-up area
# 14                 Semi built-up area total
# 15                              Mining area
# 16                            Building site
# 17                 Other semi built-up area
# 18                               Recreation
# 19                         Recreation total
# 20                   Park and public garden
# 21                            Sport grounds
# 22                   Other recreation usage
# 23                              Agriculture
# 24                        Agriculture total
# 25                              Greenhouses
# 26                 Other agricultural usage
# 27                      Woodland and nature
# 28                Woodland and nature total
# 29                                 Woodland
# 30                        Natural open area
# 31                                    Water
# 32                              Water total
# 33                       Inland water total
# 34                        Tidal water total
#
#                                           Description  MapYear ReleasePolicy  \
# 0                                                          NaN           NaN
# 1                                                          NaN         False
# 2                   Total surface of the Netherlands.      NaN           NaN
# 3   Area in use for traffic and transport on roads...      NaN           NaN
# 4           Total area of the main group ‘Transport’.      NaN           NaN
# 5   Area in use for traffic and transport on railw...      NaN           NaN
# 6   Area in use for traffic and transport over the...      NaN           NaN
# 7   Area in use for traffic and transport in the a...      NaN           NaN
# 8   Area in use for residents, work, shopping, cul...      NaN           NaN
# 9       Total area of the main group ‘Built-on area’.      NaN           NaN
# 10  Area mainly used for residents, including prim...      NaN           NaN
# 11  Area in use for industry, retail and business ...      NaN           NaN
# 12  Area in use by social and cultural facilities ...      NaN           NaN
# 13  Area with a certain amount of paving, not in u...      NaN           NaN
# 14  Total area of the main group ‘Semi built-up ar...      NaN           NaN
# 15  Area for winning materials from the bottom or ...      NaN           NaN
# 16  Area in use for construction.\r\n\r\nincluding...      NaN           NaN
# 17  Area of other use with a certain amount of pav...      NaN           NaN
# 18                        Area in use for recreation.      NaN           NaN
# 19         Total area of the main group ‘Recreation’.      NaN           NaN
# 20  Green area in use for relaxation.\r\n\r\nInclu...      NaN           NaN
# 21  Area in use for sport activities.\r\n\r\nInclu...      NaN           NaN
# 22  Area of allotment gardens, for daytrips like z...      NaN           NaN
# 23                              Area for agriculture.      NaN           NaN
# 24        Total area of the main group ‘Agriculture’.      NaN           NaN
# 25  Area in use for agriculture in greenhouses.\r\...      NaN           NaN
# 26  Area for agriculture without glass, like pastu...      NaN           NaN
# 27             Area with forest or natural open area.      NaN           NaN
# 28  Total area of the main group ‘Woodland and nat...      NaN           NaN
# 29  Area with trees for wood production and nature...      NaN           NaN
# 30  Open area with a wet or dry surface, mainly na...      NaN           NaN
# 31                                               None      NaN           NaN
# 32               Total area of the main group ‘Water’      NaN           NaN
# 33  Inland water in use as waterway, recreational ...      NaN           NaN
# 34               Water outside the average high tide.      NaN           NaN
#
#    Datatype Unit  Decimals     Default PresentationType
# 0       NaN  NaN       NaN         NaN              NaN
# 1       NaN  NaN       NaN         NaN              NaN
# 2      Long  km2       0.0  Impossible         Absolute
# 3       NaN  NaN       NaN         NaN              NaN
# 4      Long  km2       0.0  Impossible         Absolute
# 5      Long  km2       0.0  Impossible         Absolute
# 6      Long  km2       0.0  Impossible         Absolute
# 7      Long  km2       0.0  Impossible         Absolute
# 8       NaN  NaN       NaN         NaN              NaN
# 9      Long  km2       0.0  Impossible         Absolute
# 10     Long  km2       0.0  Impossible         Absolute
# 11     Long  km2       0.0  Impossible         Absolute
# 12     Long  km2       0.0  Impossible         Absolute
# 13      NaN  NaN       NaN         NaN              NaN
# 14     Long  km2       0.0  Impossible         Absolute
# 15     Long  km2       0.0  Impossible         Absolute
# 16     Long  km2       0.0  Impossible         Absolute
# 17     Long  km2       0.0  Impossible         Absolute
# 18      NaN  NaN       NaN         NaN              NaN
# 19     Long  km2       0.0  Impossible         Absolute
# 20     Long  km2       0.0  Impossible         Absolute
# 21     Long  km2       0.0  Impossible         Absolute
# 22     Long  km2       0.0  Impossible         Absolute
# 23      NaN  NaN       NaN         NaN              NaN
# 24     Long  km2       0.0  Impossible         Absolute
# 25     Long  km2       0.0  Impossible         Absolute
# 26     Long  km2       0.0  Impossible         Absolute
# 27      NaN  NaN       NaN         NaN              NaN
# 28     Long  km2       0.0  Impossible         Absolute
# 29     Long  km2       0.0  Impossible         Absolute
# 30     Long  km2       0.0  Impossible         Absolute
# 31      NaN  NaN       NaN         NaN              NaN
# 32     Long  km2       0.0  Impossible         Absolute
# 33     Long  km2       0.0  Impossible         Absolute
# 34     Long  km2       0.0  Impossible         Absolute

# %%
table
# Out:
#         ID          Regions Periods  TotalSurface_1  TransportTotal_2  \
# 0        0  The Netherlands    1900         32550.0               NaN
# 1        1  The Netherlands    1905         32570.0               NaN
# 2        2  The Netherlands    1906         32570.0               NaN
# 3        3  The Netherlands    1907         32570.0               NaN
# 4        4  The Netherlands    1908             NaN               NaN
# ...    ...              ...     ...             ...               ...
# 1542  1542     Limburg (PV)    2018          2210.0               NaN
# 1543  1543     Limburg (PV)    2019          2210.0               NaN
# 1544  1544     Limburg (PV)    2020          2210.0               NaN
# 1545  1545     Limburg (PV)    2021          2210.0               NaN
# 1546  1546     Limburg (PV)    2022          2210.0               NaN
#
#       Railroad_3  MainRoad_4  Airport_5  BuiltUpAreaTotal_6  Residential_7  \
# 0            NaN         NaN        NaN                 NaN            NaN
# 1            NaN         NaN        NaN                 NaN            NaN
# 2            NaN         NaN        NaN                 NaN            NaN
# 3            NaN         NaN        NaN                 NaN            NaN
# 4            NaN         NaN        NaN                 NaN            NaN
# ...          ...         ...        ...                 ...            ...
# 1542         NaN         NaN        NaN                 NaN            NaN
# 1543         NaN         NaN        NaN                 NaN            NaN
# 1544         NaN         NaN        NaN                 NaN            NaN
# 1545         NaN         NaN        NaN                 NaN            NaN
# 1546         NaN         NaN        NaN                 NaN            NaN
#
#       ...  OtherRecreationUsage_17  AgricultureTotal_18  Greenhouses_19  \
# 0     ...                      NaN                  NaN             NaN
# 1     ...                      NaN                  NaN             NaN
# 2     ...                      NaN                  NaN             NaN
# 3     ...                      NaN                  NaN             NaN
# 4     ...                      NaN                  NaN             NaN
# ...   ...                      ...                  ...             ...
# 1542  ...                      NaN                  NaN             NaN
# 1543  ...                      NaN                  NaN             NaN
# 1544  ...                      NaN                  NaN             NaN
# 1545  ...                      NaN                  NaN             NaN
# 1546  ...                      NaN                  NaN             NaN
#
#       OtherAgriculturalUsage_20  WoodlandAndNatureTotal_21  Woodland_22  \
# 0                       21160.0                     8760.0       2520.0
# 1                       21270.0                     8410.0       2570.0
# 2                           NaN                     8360.0       2570.0
# 3                           NaN                     8320.0       2580.0
# 4                           NaN                        NaN          NaN
# ...                         ...                        ...          ...
# 1542                        NaN                        NaN          NaN
# 1543                        NaN                        NaN          NaN
# 1544                        NaN                        NaN          NaN
# 1545                        NaN                        NaN          NaN
# 1546                        NaN                        NaN          NaN
#
#       NaturalOpenArea_23  WaterTotal_24  InlandWaterTotal_25  \
# 0                 6240.0          910.0                  NaN
# 1                 5840.0          900.0                  NaN
# 2                 5790.0          890.0                  NaN
# 3                 5740.0          890.0                  NaN
# 4                    NaN            NaN                  NaN
# ...                  ...            ...                  ...
# 1542                 NaN            NaN                  NaN
# 1543                 NaN            NaN                  NaN
# 1544                 NaN            NaN                  NaN
# 1545                 NaN            NaN                  NaN
# 1546                 NaN            NaN                  NaN
#
#       TidalWaterTotal_26
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 1542                 NaN
# 1543                 NaN
# 1544                 NaN
# 1545                 NaN
# 1546                 NaN
#
# [1547 rows x 29 columns]

# %%
client = bigquery.Client()

def df_to_bq(df, table_id):
    # Upload DataFrame to BigQuery
    job = client.load_table_from_dataframe(df, table_id)
    job.result()  # Wait for the job to complete

    print(f"Loaded {job.output_rows} rows into {table_id}.")

# %%
# Define table ID and schema
table_id = "boreal-logic-446611-v5.cbs.firsttable"

df_to_bq(table, table_id)
# Out:
# Loaded 1547 rows into boreal-logic-446611-v5.cbs.firsttable.

# %% [markdown]
# # SQLITE

# %%
conn = sqlite3.connect('database.db')
cursor = conn.cursor()

# %%
conn.close()

# %%
def upload_tables(ids, size_limit = 2147483645, max_count = None): # Size limit is 200 MB
    if max_count is not None:
        ids = ids[:max_count]
    for id in tqdm(ids, desc="Uploading tables", unit="table"):
        table = pd.DataFrame(cbsodata.get_data(id))
        if table.memory_usage().sum() > size_limit:
            print(f"Table {id} is too large to upload.")
            continue
        table.to_sql(id, conn, if_exists='replace', index=False)

# %%
table.memory_usage(deep=True).sum()/1024**2
# Out:
# np.float64(0.5167198181152344)

# %%
1073741824/5
# Out:
# 214748364.8

# %%
tables = cbsodata.get_table_list()

# %%
eng_ids = return_english_tables(tables)
eng_ids = eng_ids[262:] # eng_ids[257] has not been uploaded yet

upload_tables(eng_ids)
# Out:
# Uploading tables:   0%|          | 0/764 [00:44<?, ?table/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 4
#       1 eng_ids = return_english_tables(tables)
#       2 eng_ids = eng_ids[262:] # eng_ids[257] has not been uploaded yet
# ----> 4 upload_tables(eng_ids)
#
# Cell In[31], line 5, in upload_tables(ids, size_limit, max_count)
#       3     ids = ids[:max_count]
#       4 for id in tqdm(ids, desc="Uploading tables", unit="table"):
# ----> 5     table = pd.DataFrame(cbsodata.get_data(id))
#       6     if table.memory_usage().sum() > size_limit:
#       7         print(f"Table {id} is too large to upload.")
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\cbsodata\cbsodata3.py:480, in get_data(table_id, dir, typed, select, filters, catalog_url, **kwargs)
#     451 """Get the CBS data table.
#     452
#     453 Parameters
#    (...)
#     475     The requested data.
#     476 """
#     478 _catalog_url = _get_catalog_url(catalog_url)
# --> 480 metadata = download_data(
#     481     table_id,
#     482     dir=dir,
#     483     typed=typed,
#     484     select=select,
#     485     filters=filters,
#     486     catalog_url=_catalog_url,
#     487     **kwargs,
#     488 )
#     490 if "TypedDataSet" in metadata.keys():
#     491     data = metadata["TypedDataSet"]
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\cbsodata\cbsodata3.py:301, in download_data(table_id, dir, typed, select, filters, catalog_url, **kwargs)
#     298 for table_name in metadata_table_names:
#     299     # download table
#     300     if table_name in ["TypedDataSet", "UntypedDataSet"]:
# --> 301         metadata = _download_metadata(
#     302             table_id,
#     303             table_name,
#     304             select=select,
#     305             filters=filters,
#     306             catalog_url=_catalog_url,
#     307             **kwargs,
#     308         )
#     309     else:
#     310         metadata = _download_metadata(
#     311             table_id, table_name, catalog_url=_catalog_url, **kwargs
#     312         )
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\cbsodata\cbsodata3.py:176, in _download_metadata(table_id, metadata_name, select, filters, catalog_url, **kwargs)
#     172 p = Request("GET", url, params=params).prepare()
#     174 logging.info("Download " + p.url)
# --> 176 r = s.send(p, **request_kwargs)
#     177 r.raise_for_status()
#     178 r.encoding = "utf-8"
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\requests\models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\urllib3\response.py:1060, in HTTPResponse.stream(self, amt, decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060         data = self.read(amt=amt, decode_content=decode_content)
#    1062         if data:
#    1063             yield data
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\urllib3\response.py:949, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     946     if len(self._decoded_buffer) >= amt:
#     947         return self._decoded_buffer.get(amt)
# --> 949 data = self._raw_read(amt)
#     951 flush_decoder = amt is None or (amt != 0 and not data)
#     953 if not data and len(self._decoded_buffer) == 0:
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\urllib3\response.py:873, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
#     872 with self._error_catcher():
# --> 873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874     if amt is not None and amt != 0 and not data:
#     875         # Platform-specific: Buggy versions of Python.
#     876         # Close the connection when no data is returned
#    (...)
#     881         # not properly close the connection in all cases. There is
#     882         # no harm in redundantly calling close.
#     883         self._fp.close()
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\urllib3\response.py:856, in HTTPResponse._fp_read(self, amt, read1)
#     853     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     854 else:
#     855     # StringIO doesn't like amt=None
# --> 856     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\anaconda3\Lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
metadata = pd.DataFrame(cbsodata.get_meta('37105ENG',name= 'DataProperties'))
# Out:
#           ID                         FarmTypes            Regions Periods  \
# 0          0                    All farm types          Nederland    2000
# 1          1                    All farm types          Nederland    2001
# 2          2                    All farm types          Nederland    2002
# 3          3                    All farm types          Nederland    2003
# 4          4                    All farm types          Nederland    2004
# ...      ...                               ...                ...     ...
# 30820  30820  Specialist mixed crops/livestock  Zuid-Limburg (LB)    2020
# 30821  30821  Specialist mixed crops/livestock  Zuid-Limburg (LB)    2021
# 30822  30822  Specialist mixed crops/livestock  Zuid-Limburg (LB)    2022
# 30823  30823  Specialist mixed crops/livestock  Zuid-Limburg (LB)    2023
# 30824  30824  Specialist mixed crops/livestock  Zuid-Limburg (LB)    2024
#
#        NumberOfFarmsTotal_1  LandUseTotal_2  UtilisedAgriculturalAreaUAA_3  \
# 0                     97389     212737529.0                      197550427
# 1                     92647     207711643.0                      194613178
# 2                     89479     209973386.0                      196407461
# 3                     85408     209745968.0                      194564993
# 4                     83794     207968902.0                      194940340
# ...                     ...             ...                            ...
# 30820                    88        300849.0                         293601
# 30821                    89             NaN                         297779
# 30822                    71             NaN                         278537
# 30823                    75        281658.0                         276587
# 30824                    66             NaN                         264004
#
#        OtherLand_4  LandUseTotal_5  UtilisedAgriculturalAreaUAA_6  ...  \
# 0       15187102.0         97389.0                          95944  ...
# 1       13098465.0         92647.0                          91240  ...
# 2       13565925.0         89479.0                          88075  ...
# 3       15180975.0         85408.0                          84141  ...
# 4       13028562.0         83794.0                          82575  ...
# ...            ...             ...                            ...  ...
# 30820       7248.0            88.0                             88  ...
# 30821          NaN             NaN                             89  ...
# 30822          NaN             NaN                             71  ...
# 30823       5071.0            75.0                             75  ...
# 30824          NaN             NaN                             66  ...
#
#        ChickensTotal_140  LayingHens_141  ParentBirdsOfLayingHens_142  \
# 0                   3860            2292                          NaN
# 1                   3560            2145                          NaN
# 2                   3358            1880                          NaN
# 3                   2446            1360                          NaN
# 4                   2768            1710                          NaN
# ...                  ...             ...                          ...
# 30820                  0               0                          0.0
# 30821                  0               0                          0.0
# 30822                  0               0                          0.0
# 30823                  0               0                          0.0
# 30824                  0               0                          0.0
#
#        Broilers_143  ParentBirdsOfBroilers_144  Turkeys_145  \
# 0              1094                        520          121
# 1              1027                        430          120
# 2              1096                        418          112
# 3               777                        330           80
# 4               771                        314           92
# ...             ...                        ...          ...
# 30820             0                          0            0
# 30821             0                          0            0
# 30822             0                          0            0
# 30823             0                          0            0
# 30824             0                          0            0
#
#        DucksForFattening_146  OtherPoultry_147  Rabbits_148  FurredAnimals_149
# 0                        114               124          201              192.0
# 1                        100               113          183              187.0
# 2                         97               103          166              183.0
# 3                         80                92          152              183.0
# 4                         74                78          147              180.0
# ...                      ...               ...          ...                ...
# 30820                      0                 0            0                0.0
# 30821                      0                 0            0                NaN
# 30822                      0                 0            0                NaN
# 30823                      0                 0            0                NaN
# 30824                      0                 0            0                NaN
#
# [30825 rows x 153 columns]

# %% [markdown]
# ## Metadata

# %%
# Exploration

names = ['TableInfos', 'UntypedDataSet', 'TypedDataSet', 'DataProperties', 'CategoryGroups', 'Geschlecht', 'Alter', 'Region', 'Perioden']

names_that_dont_work = ['Geschlecht', 'Alter', 'Region', 'Perioden'] # These supposedly valid names (from the API web) don't work

names = [name for name in names if name not in names_that_dont_work]

for name in names:
    metadata = pd.DataFrame(cbsodata.get_meta('37105ENG',name= name)) 
    print(name)
    print(metadata)
    print('-----------------')
# Out:
# TableInfos
#    ID                                              Title  \
# 0   0  Land use; main categories; regional, 1900 onwards
#
#                          ShortTitle Identifier  \
# 0  Land use; regional, 1900 onwards   37105ENG
#
#                                              Summary             Modified  \
# 0  Traffic area, Built up area, Forest, Natural a...  2022-11-30T02:00:00
#
#   ReasonDelivery ExplanatoryText Language Catalog  ...     Period  \
# 0         Update                       en     CBS  ...  1900-2017
#
#                                     ShortDescription  \
# 0  \nThis table provides information about the la...
#
#                                          Description  \
# 0  CONTENTS\r\n\r\n1. General information\r\n2. D...
#
#                                  DefaultPresentation  \
# 0  ts=1668751650543&graphtype=Table&r=Topics&k=Re...
#
#                                     DefaultSelection      GraphTypes  \
# 0  $filter=((Periods eq '1900JJ00') or (Periods e...  Table,Bar,Line
#
#   OutputStatus Source     MetaDataModified SearchPriority
# 0      Regular   CBS.  2022-11-30T02:00:00              2
#
# [1 rows x 21 columns]
# -----------------
# UntypedDataSet
#         ID Regions   Periods TotalSurface_1 TransportTotal_2 Railroad_3  \
# 0        0  NL01    1900JJ00          32550                .          .
# 1        1  NL01    1905JJ00          32570                .          .
# 2        2  NL01    1906JJ00          32570                .          .
# 3        3  NL01    1907JJ00          32570                .          .
# 4        4  NL01    1908JJ00              .                .          .
# ...    ...     ...       ...            ...              ...        ...
# 1542  1542  PV31    2018JJ00           2210                .          .
# 1543  1543  PV31    2019JJ00           2210                .          .
# 1544  1544  PV31    2020JJ00           2210                .          .
# 1545  1545  PV31    2021JJ00           2210                .          .
# 1546  1546  PV31    2022JJ00           2210                .          .
#
#      MainRoad_4 Airport_5 BuiltUpAreaTotal_6 Residential_7  ...  \
# 0             .         .                  .             .  ...
# 1             .         .                  .             .  ...
# 2             .         .                  .             .  ...
# 3             .         .                  .             .  ...
# 4             .         .                  .             .  ...
# ...         ...       ...                ...           ...  ...
# 1542          .         .                  .             .  ...
# 1543          .         .                  .             .  ...
# 1544          .         .                  .             .  ...
# 1545          .         .                  .             .  ...
# 1546          .         .                  .             .  ...
#
#      OtherRecreationUsage_17 AgricultureTotal_18 Greenhouses_19  \
# 0                          .                   .              .
# 1                          .                   .              .
# 2                          .                   .              .
# 3                          .                   .              .
# 4                          .                   .              .
# ...                      ...                 ...            ...
# 1542                       .                   .              .
# 1543                       .                   .              .
# 1544                       .                   .              .
# 1545                       .                   .              .
# 1546                       .                   .              .
#
#      OtherAgriculturalUsage_20 WoodlandAndNatureTotal_21 Woodland_22  \
# 0                        21160                      8760        2520
# 1                        21270                      8410        2570
# 2                            .                      8360        2570
# 3                            .                      8320        2580
# 4                            .                         .           .
# ...                        ...                       ...         ...
# 1542                         .                         .           .
# 1543                         .                         .           .
# 1544                         .                         .           .
# 1545                         .                         .           .
# 1546                         .                         .           .
#
#      NaturalOpenArea_23 WaterTotal_24 InlandWaterTotal_25 TidalWaterTotal_26
# 0                  6240           910                   .                  .
# 1                  5840           900                   .                  .
# 2                  5790           890                   .                  .
# 3                  5740           890                   .                  .
# 4                     .             .                   .                  .
# ...                 ...           ...                 ...                ...
# 1542                  .             .                   .
# 1543                  .             .                   .
# 1544                  .             .                   .
# 1545                  .             .                   .
# 1546                  .             .                   .
#
# [1547 rows x 29 columns]
# -----------------
# TypedDataSet
#         ID Regions   Periods  TotalSurface_1  TransportTotal_2  Railroad_3  \
# 0        0  NL01    1900JJ00         32550.0               NaN         NaN
# 1        1  NL01    1905JJ00         32570.0               NaN         NaN
# 2        2  NL01    1906JJ00         32570.0               NaN         NaN
# 3        3  NL01    1907JJ00         32570.0               NaN         NaN
# 4        4  NL01    1908JJ00             NaN               NaN         NaN
# ...    ...     ...       ...             ...               ...         ...
# 1542  1542  PV31    2018JJ00          2210.0               NaN         NaN
# 1543  1543  PV31    2019JJ00          2210.0               NaN         NaN
# 1544  1544  PV31    2020JJ00          2210.0               NaN         NaN
# 1545  1545  PV31    2021JJ00          2210.0               NaN         NaN
# 1546  1546  PV31    2022JJ00          2210.0               NaN         NaN
#
#       MainRoad_4  Airport_5  BuiltUpAreaTotal_6  Residential_7  ...  \
# 0            NaN        NaN                 NaN            NaN  ...
# 1            NaN        NaN                 NaN            NaN  ...
# 2            NaN        NaN                 NaN            NaN  ...
# 3            NaN        NaN                 NaN            NaN  ...
# 4            NaN        NaN                 NaN            NaN  ...
# ...          ...        ...                 ...            ...  ...
# 1542         NaN        NaN                 NaN            NaN  ...
# 1543         NaN        NaN                 NaN            NaN  ...
# 1544         NaN        NaN                 NaN            NaN  ...
# 1545         NaN        NaN                 NaN            NaN  ...
# 1546         NaN        NaN                 NaN            NaN  ...
#
#       OtherRecreationUsage_17  AgricultureTotal_18  Greenhouses_19  \
# 0                         NaN                  NaN             NaN
# 1                         NaN                  NaN             NaN
# 2                         NaN                  NaN             NaN
# 3                         NaN                  NaN             NaN
# 4                         NaN                  NaN             NaN
# ...                       ...                  ...             ...
# 1542                      NaN                  NaN             NaN
# 1543                      NaN                  NaN             NaN
# 1544                      NaN                  NaN             NaN
# 1545                      NaN                  NaN             NaN
# 1546                      NaN                  NaN             NaN
#
#       OtherAgriculturalUsage_20  WoodlandAndNatureTotal_21  Woodland_22  \
# 0                       21160.0                     8760.0       2520.0
# 1                       21270.0                     8410.0       2570.0
# 2                           NaN                     8360.0       2570.0
# 3                           NaN                     8320.0       2580.0
# 4                           NaN                        NaN          NaN
# ...                         ...                        ...          ...
# 1542                        NaN                        NaN          NaN
# 1543                        NaN                        NaN          NaN
# 1544                        NaN                        NaN          NaN
# 1545                        NaN                        NaN          NaN
# 1546                        NaN                        NaN          NaN
#
#       NaturalOpenArea_23  WaterTotal_24  InlandWaterTotal_25  \
# 0                 6240.0          910.0                  NaN
# 1                 5840.0          900.0                  NaN
# 2                 5790.0          890.0                  NaN
# 3                 5740.0          890.0                  NaN
# 4                    NaN            NaN                  NaN
# ...                  ...            ...                  ...
# 1542                 NaN            NaN                  NaN
# 1543                 NaN            NaN                  NaN
# 1544                 NaN            NaN                  NaN
# 1545                 NaN            NaN                  NaN
# 1546                 NaN            NaN                  NaN
#
#       TidalWaterTotal_26
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 1542                 NaN
# 1543                 NaN
# 1544                 NaN
# 1545                 NaN
# 1546                 NaN
#
# [1547 rows x 29 columns]
# -----------------
# DataProperties
#                  odata.type  ID  Position  ParentID           Type  \
# 0    Cbs.OData.GeoDimension   0       0.0       NaN   GeoDimension
# 1   Cbs.OData.TimeDimension   1       1.0       NaN  TimeDimension
# 2           Cbs.OData.Topic   2       2.0       NaN          Topic
# 3      Cbs.OData.TopicGroup   3       NaN       NaN     TopicGroup
# 4           Cbs.OData.Topic   4       3.0       3.0          Topic
# 5           Cbs.OData.Topic   5       4.0       3.0          Topic
# 6           Cbs.OData.Topic   6       5.0       3.0          Topic
# 7           Cbs.OData.Topic   7       6.0       3.0          Topic
# 8      Cbs.OData.TopicGroup   8       NaN       NaN     TopicGroup
# 9           Cbs.OData.Topic   9       7.0       8.0          Topic
# 10          Cbs.OData.Topic  10       8.0       8.0          Topic
# 11          Cbs.OData.Topic  11       9.0       8.0          Topic
# 12          Cbs.OData.Topic  12      10.0       8.0          Topic
# 13     Cbs.OData.TopicGroup  13       NaN       NaN     TopicGroup
# 14          Cbs.OData.Topic  14      11.0      13.0          Topic
# 15          Cbs.OData.Topic  15      12.0      13.0          Topic
# 16          Cbs.OData.Topic  16      13.0      13.0          Topic
# 17          Cbs.OData.Topic  17      14.0      13.0          Topic
# 18     Cbs.OData.TopicGroup  18       NaN       NaN     TopicGroup
# 19          Cbs.OData.Topic  19      15.0      18.0          Topic
# 20          Cbs.OData.Topic  20      16.0      18.0          Topic
# 21          Cbs.OData.Topic  21      17.0      18.0          Topic
# 22          Cbs.OData.Topic  22      18.0      18.0          Topic
# 23     Cbs.OData.TopicGroup  23       NaN       NaN     TopicGroup
# 24          Cbs.OData.Topic  24      19.0      23.0          Topic
# 25          Cbs.OData.Topic  25      20.0      23.0          Topic
# 26          Cbs.OData.Topic  26      21.0      23.0          Topic
# 27     Cbs.OData.TopicGroup  27       NaN       NaN     TopicGroup
# 28          Cbs.OData.Topic  28      22.0      27.0          Topic
# 29          Cbs.OData.Topic  29      23.0      27.0          Topic
# 30          Cbs.OData.Topic  30      24.0      27.0          Topic
# 31     Cbs.OData.TopicGroup  31       NaN       NaN     TopicGroup
# 32          Cbs.OData.Topic  32      25.0      31.0          Topic
# 33          Cbs.OData.Topic  33      26.0      31.0          Topic
# 34          Cbs.OData.Topic  34      27.0      31.0          Topic
#
#                                      Key  \
# 0                                Regions
# 1                                Periods
# 2                         TotalSurface_1
# 3
# 4                       TransportTotal_2
# 5                             Railroad_3
# 6                             MainRoad_4
# 7                              Airport_5
# 8
# 9                     BuiltUpAreaTotal_6
# 10                         Residential_7
# 11  IndustryBusinessPublicInstitutions_8
# 12             SocioCulturalFacilities_9
# 13
# 14               SemiBuiltUpAreaTotal_10
# 15                         MiningArea_11
# 16                       BuildingSite_12
# 17               OtherSemiBuiltUpArea_13
# 18
# 19                    RecreationTotal_14
# 20                ParkAndPublicGarden_15
# 21                       SportGrounds_16
# 22               OtherRecreationUsage_17
# 23
# 24                   AgricultureTotal_18
# 25                        Greenhouses_19
# 26             OtherAgriculturalUsage_20
# 27
# 28             WoodlandAndNatureTotal_21
# 29                           Woodland_22
# 30                    NaturalOpenArea_23
# 31
# 32                         WaterTotal_24
# 33                   InlandWaterTotal_25
# 34                    TidalWaterTotal_26
#
#                                       Title  \
# 0                                   Regions
# 1                                   Periods
# 2                             Total surface
# 3                                 Transport
# 4                           Transport total
# 5                                  Railroad
# 6                                 Main road
# 7                                   Airport
# 8                             Built-up area
# 9                       Built-up area total
# 10                              Residential
# 11  Industry, business, public institutions
# 12                Socio-cultural facilities
# 13                       Semi built-up area
# 14                 Semi built-up area total
# 15                              Mining area
# 16                            Building site
# 17                 Other semi built-up area
# 18                               Recreation
# 19                         Recreation total
# 20                   Park and public garden
# 21                            Sport grounds
# 22                   Other recreation usage
# 23                              Agriculture
# 24                        Agriculture total
# 25                              Greenhouses
# 26                 Other agricultural usage
# 27                      Woodland and nature
# 28                Woodland and nature total
# 29                                 Woodland
# 30                        Natural open area
# 31                                    Water
# 32                              Water total
# 33                       Inland water total
# 34                        Tidal water total
#
#                                           Description  MapYear ReleasePolicy  \
# 0                                                          NaN           NaN
# 1                                                          NaN         False
# 2                   Total surface of the Netherlands.      NaN           NaN
# 3   Area in use for traffic and transport on roads...      NaN           NaN
# 4           Total area of the main group ‘Transport’.      NaN           NaN
# 5   Area in use for traffic and transport on railw...      NaN           NaN
# 6   Area in use for traffic and transport over the...      NaN           NaN
# 7   Area in use for traffic and transport in the a...      NaN           NaN
# 8   Area in use for residents, work, shopping, cul...      NaN           NaN
# 9       Total area of the main group ‘Built-on area’.      NaN           NaN
# 10  Area mainly used for residents, including prim...      NaN           NaN
# 11  Area in use for industry, retail and business ...      NaN           NaN
# 12  Area in use by social and cultural facilities ...      NaN           NaN
# 13  Area with a certain amount of paving, not in u...      NaN           NaN
# 14  Total area of the main group ‘Semi built-up ar...      NaN           NaN
# 15  Area for winning materials from the bottom or ...      NaN           NaN
# 16  Area in use for construction.\r\n\r\nincluding...      NaN           NaN
# 17  Area of other use with a certain amount of pav...      NaN           NaN
# 18                        Area in use for recreation.      NaN           NaN
# 19         Total area of the main group ‘Recreation’.      NaN           NaN
# 20  Green area in use for relaxation.\r\n\r\nInclu...      NaN           NaN
# 21  Area in use for sport activities.\r\n\r\nInclu...      NaN           NaN
# 22  Area of allotment gardens, for daytrips like z...      NaN           NaN
# 23                              Area for agriculture.      NaN           NaN
# 24        Total area of the main group ‘Agriculture’.      NaN           NaN
# 25  Area in use for agriculture in greenhouses.\r\...      NaN           NaN
# 26  Area for agriculture without glass, like pastu...      NaN           NaN
# 27             Area with forest or natural open area.      NaN           NaN
# 28  Total area of the main group ‘Woodland and nat...      NaN           NaN
# 29  Area with trees for wood production and nature...      NaN           NaN
# 30  Open area with a wet or dry surface, mainly na...      NaN           NaN
# 31                                               None      NaN           NaN
# 32               Total area of the main group ‘Water’      NaN           NaN
# 33  Inland water in use as waterway, recreational ...      NaN           NaN
# 34               Water outside the average high tide.      NaN           NaN
#
#    Datatype Unit  Decimals     Default PresentationType
# 0       NaN  NaN       NaN         NaN              NaN
# 1       NaN  NaN       NaN         NaN              NaN
# 2      Long  km2       0.0  Impossible         Absolute
# 3       NaN  NaN       NaN         NaN              NaN
# 4      Long  km2       0.0  Impossible         Absolute
# 5      Long  km2       0.0  Impossible         Absolute
# 6      Long  km2       0.0  Impossible         Absolute
# 7      Long  km2       0.0  Impossible         Absolute
# 8       NaN  NaN       NaN         NaN              NaN
# 9      Long  km2       0.0  Impossible         Absolute
# 10     Long  km2       0.0  Impossible         Absolute
# 11     Long  km2       0.0  Impossible         Absolute
# 12     Long  km2       0.0  Impossible         Absolute
# 13      NaN  NaN       NaN         NaN              NaN
# 14     Long  km2       0.0  Impossible         Absolute
# 15     Long  km2       0.0  Impossible         Absolute
# 16     Long  km2       0.0  Impossible         Absolute
# 17     Long  km2       0.0  Impossible         Absolute
# 18      NaN  NaN       NaN         NaN              NaN
# 19     Long  km2       0.0  Impossible         Absolute
# 20     Long  km2       0.0  Impossible         Absolute
# 21     Long  km2       0.0  Impossible         Absolute
# 22     Long  km2       0.0  Impossible         Absolute
# 23      NaN  NaN       NaN         NaN              NaN
# 24     Long  km2       0.0  Impossible         Absolute
# 25     Long  km2       0.0  Impossible         Absolute
# 26     Long  km2       0.0  Impossible         Absolute
# 27      NaN  NaN       NaN         NaN              NaN
# 28     Long  km2       0.0  Impossible         Absolute
# 29     Long  km2       0.0  Impossible         Absolute
# 30     Long  km2       0.0  Impossible         Absolute
# 31      NaN  NaN       NaN         NaN              NaN
# 32     Long  km2       0.0  Impossible         Absolute
# 33     Long  km2       0.0  Impossible         Absolute
# 34     Long  km2       0.0  Impossible         Absolute
# -----------------
# CategoryGroups
# Empty DataFrame
# Columns: []
# Index: []
# -----------------

# %%
pd.DataFrame(cbsodata.get_data('37105ENG'))
# Out:
#         ID          Regions Periods  TotalSurface_1  TransportTotal_2  \
# 0        0  The Netherlands    1900         32550.0               NaN
# 1        1  The Netherlands    1905         32570.0               NaN
# 2        2  The Netherlands    1906         32570.0               NaN
# 3        3  The Netherlands    1907         32570.0               NaN
# 4        4  The Netherlands    1908             NaN               NaN
# ...    ...              ...     ...             ...               ...
# 1542  1542     Limburg (PV)    2018          2210.0               NaN
# 1543  1543     Limburg (PV)    2019          2210.0               NaN
# 1544  1544     Limburg (PV)    2020          2210.0               NaN
# 1545  1545     Limburg (PV)    2021          2210.0               NaN
# 1546  1546     Limburg (PV)    2022          2210.0               NaN
#
#       Railroad_3  MainRoad_4  Airport_5  BuiltUpAreaTotal_6  Residential_7  \
# 0            NaN         NaN        NaN                 NaN            NaN
# 1            NaN         NaN        NaN                 NaN            NaN
# 2            NaN         NaN        NaN                 NaN            NaN
# 3            NaN         NaN        NaN                 NaN            NaN
# 4            NaN         NaN        NaN                 NaN            NaN
# ...          ...         ...        ...                 ...            ...
# 1542         NaN         NaN        NaN                 NaN            NaN
# 1543         NaN         NaN        NaN                 NaN            NaN
# 1544         NaN         NaN        NaN                 NaN            NaN
# 1545         NaN         NaN        NaN                 NaN            NaN
# 1546         NaN         NaN        NaN                 NaN            NaN
#
#       ...  OtherRecreationUsage_17  AgricultureTotal_18  Greenhouses_19  \
# 0     ...                      NaN                  NaN             NaN
# 1     ...                      NaN                  NaN             NaN
# 2     ...                      NaN                  NaN             NaN
# 3     ...                      NaN                  NaN             NaN
# 4     ...                      NaN                  NaN             NaN
# ...   ...                      ...                  ...             ...
# 1542  ...                      NaN                  NaN             NaN
# 1543  ...                      NaN                  NaN             NaN
# 1544  ...                      NaN                  NaN             NaN
# 1545  ...                      NaN                  NaN             NaN
# 1546  ...                      NaN                  NaN             NaN
#
#       OtherAgriculturalUsage_20  WoodlandAndNatureTotal_21  Woodland_22  \
# 0                       21160.0                     8760.0       2520.0
# 1                       21270.0                     8410.0       2570.0
# 2                           NaN                     8360.0       2570.0
# 3                           NaN                     8320.0       2580.0
# 4                           NaN                        NaN          NaN
# ...                         ...                        ...          ...
# 1542                        NaN                        NaN          NaN
# 1543                        NaN                        NaN          NaN
# 1544                        NaN                        NaN          NaN
# 1545                        NaN                        NaN          NaN
# 1546                        NaN                        NaN          NaN
#
#       NaturalOpenArea_23  WaterTotal_24  InlandWaterTotal_25  \
# 0                 6240.0          910.0                  NaN
# 1                 5840.0          900.0                  NaN
# 2                 5790.0          890.0                  NaN
# 3                 5740.0          890.0                  NaN
# 4                    NaN            NaN                  NaN
# ...                  ...            ...                  ...
# 1542                 NaN            NaN                  NaN
# 1543                 NaN            NaN                  NaN
# 1544                 NaN            NaN                  NaN
# 1545                 NaN            NaN                  NaN
# 1546                 NaN            NaN                  NaN
#
#       TidalWaterTotal_26
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 1542                 NaN
# 1543                 NaN
# 1544                 NaN
# 1545                 NaN
# 1546                 NaN
#
# [1547 rows x 29 columns]

# %%
metadata_names_dont_work = pd.DataFrame(columns = ['ID', 'Name'])
count = 0
max_count = 5
for id in eng_ids:
    count += 1
    if count == max_count:
        break
    for name in names:
        try:
            metadata = pd.DataFrame(cbsodata.get_meta(id,name= name))
        except:
            new_entry = pd.DataFrame({'ID': [id], 'Name': [name]})
            metadata_names_dont_work = pd.concat([metadata_names_dont_work, new_entry], ignore_index=True)
            continue

metadata_names_dont_work.groupby('ID')['Name'].agg(', '.join).reset_index()
# Out:
#          ID                                 Name
# 0  37738ENG  Geschlecht, Alter, Region, Perioden
# 1  80783eng  Geschlecht, Alter, Region, Perioden
# 2  80784eng  Geschlecht, Alter, Region, Perioden
# 3  85636ENG  Geschlecht, Alter, Region, Perioden

# %% [markdown]
# Upon inspection of the different metadata names I decided that only TableInfos and DataProperties contain useful information

# %% [markdown]
# ### Table Metadata

# %%
def get_tables_database(conn = conn, exclude_metadata_tables = True):
    query = "SELECT name FROM sqlite_master WHERE type='table';"
    cursor = conn.cursor()
    cursor.execute(query)

    # Fetch all table names
    table_names = [row[0] for row in cursor.fetchall()]
    if exclude_metadata_tables:
        table_names = [name for name in table_names if 'metadata' not in name]
    return table_names

# %%
def generate_metadata_tables_df(ids, max_count=None):
    metadata_tables_list = []  # List to store DataFrames
    if max_count is not None:
        ids = ids[:max_count]
    for id in ids:
        # Fetch metadata and drop 'ID' column
        new_entry = pd.DataFrame(cbsodata.get_meta(id, name='TableInfos'))
        metadata_tables_list.append(new_entry)  # Add the DataFrame to the list

    # Concatenate all DataFrames at once
    metadata_tables = pd.concat(metadata_tables_list, ignore_index=True).drop(columns=['ID'])
    return metadata_tables

# %%
ids = get_tables_database()
metadata_tables = generate_metadata_tables_df(ids)
metadata_tables.to_sql('metadata_tables', conn, if_exists='replace', index=False)
# Out:
# 262

# %% [markdown]
# ### Column Metadata

# %%
pd.DataFrame(cbsodata.get_meta(id, name='DataProperties'))
# Out:
#                   odata.type   ID  Position  ParentID           Type  \
# 0        Cbs.OData.Dimension    0       0.0       NaN      Dimension
# 1     Cbs.OData.GeoDimension    1       1.0       NaN   GeoDimension
# 2    Cbs.OData.TimeDimension    2       2.0       NaN  TimeDimension
# 3            Cbs.OData.Topic    3       3.0       NaN          Topic
# 4       Cbs.OData.TopicGroup    4       NaN       NaN     TopicGroup
# ..                       ...  ...       ...       ...            ...
# 193          Cbs.OData.Topic  193     147.0     180.0          Topic
# 194          Cbs.OData.Topic  194     148.0     180.0          Topic
# 195          Cbs.OData.Topic  195     149.0     180.0          Topic
# 196          Cbs.OData.Topic  196     150.0     180.0          Topic
# 197          Cbs.OData.Topic  197     151.0     180.0          Topic
#
#                        Key                   Title  \
# 0                FarmTypes              Farm types
# 1                  Regions                 Regions
# 2                  Periods                 Periods
# 3     NumberOfFarmsTotal_1  Number of farms, total
# 4                                         Land use
# ..                     ...                     ...
# 193            Turkeys_145                 Turkeys
# 194  DucksForFattening_146     Ducks for fattening
# 195       OtherPoultry_147           Other poultry
# 196            Rabbits_148                 Rabbits
# 197      FurredAnimals_149          Furred animals
#
#                                            Description  MapYear ReleasePolicy  \
# 0                                                           NaN           NaN
# 1                                                 None      NaN           NaN
# 2                                                           NaN          True
# 3    Holdings that produce agricultural goods comme...      NaN           NaN
# 4                                                 None      NaN           NaN
# ..                                                 ...      ...           ...
# 193                                               None      NaN           NaN
# 194                                               None      NaN           NaN
# 195      Laying ducks, geese, guinea fowl and similar.      NaN           NaN
# 196                Weanling rabbits for meat and does.      NaN           NaN
# 197  Since 8 January 2021, there has been a ban on ...      NaN           NaN
#
#     Datatype    Unit  Decimals Default PresentationType
# 0        NaN     NaN       NaN     NaN              NaN
# 1        NaN     NaN       NaN     NaN              NaN
# 2        NaN     NaN       NaN     NaN              NaN
# 3       Long  number       0.0    Zero         Absolute
# 4        NaN     NaN       NaN     NaN              NaN
# ..       ...     ...       ...     ...              ...
# 193     Long  number       0.0    Zero         Absolute
# 194     Long  number       0.0    Zero         Absolute
# 195     Long  number       0.0    Zero         Absolute
# 196     Long  number       0.0    Zero         Absolute
# 197     Long  number       0.0    Zero         Absolute
#
# [198 rows x 15 columns]

# %%
def generate_metadata_columns_df(ids, max_count=None):
    metadata_columns_list = []  # List to store DataFrames
    if max_count is not None:
        ids = ids[:max_count]
    for id in ids:
        # Fetch metadata and drop 'ID' column
        new_entry = pd.DataFrame(cbsodata.get_meta(id, name='DataProperties'))
        new_entry['Identifier'] = id # Add the 'Identifier' column
        metadata_columns_list.append(new_entry)  # Add the DataFrame to the list

    # Concatenate all DataFrames at once
    metadata_columns = pd.concat(metadata_columns_list, ignore_index=True).drop(columns=['ID'])
    return metadata_columns

# %%
ids = get_tables_database()
metadata_columns = generate_metadata_columns_df(ids)
metadata_columns.to_sql('metadata_columns', conn, if_exists='replace', index=False)
# Out:
# C:\Users\Mario\AppData\Local\Temp\ipykernel_5888\2788774919.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   metadata_columns = pd.concat(metadata_columns_list, ignore_index=True).drop(columns=['ID'])
# 5048

# %% [markdown]
# I erased the following tables from the database:
# 85682ENG
# 85680ENG
# 85683ENG
# 85428ENG
# 84668ENG

# %%
table = pd.DataFrame(cbsodata.get_data('84668ENG'))

table.memory_usage(deep=True).sum()/1024**3
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 table = pd.DataFrame(cbsodata.get_data('84668ENG'))
#       3 table.memory_usage(deep=True).sum()/1024**3
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\cbsodata\cbsodata3.py:480, in get_data(table_id, dir, typed, select, filters, catalog_url, **kwargs)
#     451 """Get the CBS data table.
#     452
#     453 Parameters
#    (...)
#     475     The requested data.
#     476 """
#     478 _catalog_url = _get_catalog_url(catalog_url)
# --> 480 metadata = download_data(
#     481     table_id,
#     482     dir=dir,
#     483     typed=typed,
#     484     select=select,
#     485     filters=filters,
#     486     catalog_url=_catalog_url,
#     487     **kwargs,
#     488 )
#     490 if "TypedDataSet" in metadata.keys():
#     491     data = metadata["TypedDataSet"]
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\cbsodata\cbsodata3.py:301, in download_data(table_id, dir, typed, select, filters, catalog_url, **kwargs)
#     298 for table_name in metadata_table_names:
#     299     # download table
#     300     if table_name in ["TypedDataSet", "UntypedDataSet"]:
# --> 301         metadata = _download_metadata(
#     302             table_id,
#     303             table_name,
#     304             select=select,
#     305             filters=filters,
#     306             catalog_url=_catalog_url,
#     307             **kwargs,
#     308         )
#     309     else:
#     310         metadata = _download_metadata(
#     311             table_id, table_name, catalog_url=_catalog_url, **kwargs
#     312         )
#
# File c:\Users\Mario\Documents\Git\StatisticalAssistant_CBS\env\Lib\site-packages\cbsodata\cbsodata3.py:180, in _download_metadata(table_id, metadata_name, select, filters, catalog_url, **kwargs)
#     177 r.raise_for_status()
#     178 r.encoding = "utf-8"
# --> 180 res = json.loads(r.text)
#     181 data.extend(res["value"])
#     183 try:
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\anaconda3\Lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Unterminated string starting at: line 9248 column 508 (char 2795457)
