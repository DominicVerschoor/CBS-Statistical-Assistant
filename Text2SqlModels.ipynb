# %% [markdown]
# ### Imports

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, logging

# %% [markdown]
# ### Initialize T5-LM-Large model
# ###### (Pretrained on spider)

# %%
t5_model_path = 'gaussalgo/T5-LM-Large-text2sql-spider'
t5_model = AutoModelForSeq2SeqLM.from_pretrained(t5_model_path)
t5_tokenizer = AutoTokenizer.from_pretrained(t5_model_path)

# %% [markdown]
# ### Initialize Schema and input question

# %%
with open("TestData\schema.sql", "r") as file:
    schema = file.read()

question = "How many students do soccer?"
input_text = " ".join(["Question: ",question, "Schema:", schema])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\domin\AppData\Local\Temp\ipykernel_13432\4189374141.py:1: SyntaxWarning: invalid escape sequence '\s'
#   with open("TestData\schema.sql", "r") as file:

# %% [markdown]
# ## Run models

# %%
# Tokenize input
t5_model_inputs = t5_tokenizer(input_text, return_tensors="pt")

# Generate output
t5_outputs = t5_model.generate(**t5_model_inputs, max_length=1024)

# Decode output
t5_output_text = t5_tokenizer.batch_decode(t5_outputs, skip_special_tokens=True)

# print
print("T5 SQL Query:", t5_output_text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 5
#       2 t5_model_inputs = t5_tokenizer(input_text, return_tensors="pt")
#       4 # Generate output
# ----> 5 t5_outputs = t5_model.generate(**t5_model_inputs, max_length=1024)
#       7 # Decode output
#       8 t5_output_text = t5_tokenizer.batch_decode(t5_outputs, skip_special_tokens=True)
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\transformers\generation\utils.py:2064, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2060         raise ValueError("`attention_mask` passed to `generate` must be 2D.")
#    2062 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    2063     # if model is encoder decoder encoder_outputs are created and added to `model_kwargs`
# -> 2064     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    2065         inputs_tensor, model_kwargs, model_input_name, generation_config
#    2066     )
#    2068 # 5. Prepare `input_ids` which will be used for auto-regressive generation
#    2069 if self.config.is_encoder_decoder:
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\transformers\generation\utils.py:652, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name, generation_config)
#     650 encoder_kwargs["return_dict"] = True
#     651 encoder_kwargs[model_input_name] = inputs_tensor
# --> 652 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)  # type: ignore
#     654 return model_kwargs
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\transformers\models\t5\modeling_t5.py:1124, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1107     layer_outputs = self._gradient_checkpointing_func(
#    1108         layer_module.forward,
#    1109         hidden_states,
#    (...)
#    1121         cache_position,
#    1122     )
#    1123 else:
# -> 1124     layer_outputs = layer_module(
#    1125         hidden_states,
#    1126         attention_mask=causal_mask,
#    1127         position_bias=position_bias,
#    1128         encoder_hidden_states=encoder_hidden_states,
#    1129         encoder_attention_mask=encoder_extended_attention_mask,
#    1130         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1131         layer_head_mask=layer_head_mask,
#    1132         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1133         past_key_value=past_key_values,
#    1134         use_cache=use_cache,
#    1135         output_attentions=output_attentions,
#    1136         return_dict=return_dict,
#    1137         cache_position=cache_position,
#    1138     )
#    1140 # layer_outputs is a tuple with:
#    1141 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1142 if use_cache is False:
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\transformers\models\t5\modeling_t5.py:675, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict, cache_position)
#     659 def forward(
#     660     self,
#     661     hidden_states,
#    (...)
#     673     cache_position=None,
#     674 ):
# --> 675     self_attention_outputs = self.layer[0](
#     676         hidden_states,
#     677         attention_mask=attention_mask,
#     678         position_bias=position_bias,
#     679         layer_head_mask=layer_head_mask,
#     680         past_key_value=past_key_value,
#     681         use_cache=use_cache,
#     682         output_attentions=output_attentions,
#     683         cache_position=cache_position,
#     684     )
#     685     hidden_states, past_key_value = self_attention_outputs[:2]
#     686     attention_outputs = self_attention_outputs[2:]  # Keep self-attention outputs and relative position weights
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\transformers\models\t5\modeling_t5.py:593, in T5LayerSelfAttention.forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, output_attentions, cache_position)
#     581 def forward(
#     582     self,
#     583     hidden_states,
#    (...)
#     590     cache_position=None,
#     591 ):
#     592     normed_hidden_states = self.layer_norm(hidden_states)
# --> 593     attention_output = self.SelfAttention(
#     594         normed_hidden_states,
#     595         mask=attention_mask,
#     596         position_bias=position_bias,
#     597         layer_head_mask=layer_head_mask,
#     598         past_key_value=past_key_value,
#     599         use_cache=use_cache,
#     600         output_attentions=output_attentions,
#     601         cache_position=cache_position,
#     602     )
#     603     hidden_states = hidden_states + self.dropout(attention_output[0])
#     604     outputs = (hidden_states,) + attention_output[1:]  # add attentions if we output them
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\domin\anaconda3\envs\ml\Lib\site-packages\transformers\models\t5\modeling_t5.py:559, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions, cache_position)
#     556 if layer_head_mask is not None:
#     557     attn_weights = attn_weights * layer_head_mask
# --> 559 attn_output = torch.matmul(attn_weights, value_states)
#     561 attn_output = attn_output.transpose(1, 2).contiguous()
#     562 attn_output = attn_output.view(batch_size, -1, self.inner_dim)
#
# KeyboardInterrupt:
